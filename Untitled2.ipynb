# %% [markdown]
# <a href="https://colab.research.google.com/github/Raju-mia-RK/Raju/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loop Program

# %%
n=int(input())
for i in range(1,n+1):
  print(i)
# Out:
# 5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# find the factor of n value

# %%
n=int(input())
for i in range(2,n):
  if(n%i==0):
    print("factor: ",i)
# Out:
# 10
# factor:  2
# factor:  5

# %% [markdown]
# summation series

# %%
n=int(input())
sum=0
for i in range(1,n+1):
  sum=sum+i
print("sum: ",sum)
# Out:
# 10
# sum:  55

# %%
n=int(input())
sum=0.0
for i in range(2,n+1):
  sum=sum+1/i
print("sum: ",sum)
# Out:
# 5
# sum:  1.2833333333333332
